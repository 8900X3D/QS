# %%
import cv2
import matplotlib.pyplot as plt

# %%
#打开视频资源
video =cv2.VideoCapture("./aaaa.mp4")
#读取一遍    frame表示一帧
ret,frame = video.read()

# %%
plt.imshow(frame)

# %%
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %%
video=cv2.VideoCapture("./aaaa.mp4")
num=0             #计数器
save_step = 30    #间隔帧
while True:
    ret,frame =video.read()
    if not ret:
        break
    num+=1
    if num%save_step==0:
      cv2.imwrite("./demo_images/"+str(num)+".jpg",frame)


      #labelimg数据集标注
      #包安装pip install labelimg
      #输入labelimg使用

      #make sense数据集标注
      #https://www.makesense.ai/
      #在线辅助标注

      #roboflow公开数据集
      #https://public.roboflow.com/object-detection
      #https://universe.roboflow.com/
